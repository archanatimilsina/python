# %%
import cv2

# %%
img = cv2.imread("./assets/zoro.jpg")
print(img.shape)

# %%
img2=cv2.imread("./assets/xieLian.jpg")
# print(img2)
# print(len(img2))
print(img2.shape)
#

# %%
color_image = cv2.imread("./assets/zoro.jpg",cv2.IMREAD_COLOR)
print("Shape of color image:", color_image.shape)

# %%
grayscale_image = cv2.imread("./assets/xieLian.jpg",cv2.IMREAD_REDUCED_GRAYSCALE_2)
print("Shape of grayscale image:", grayscale_image.shape)

# %%
cv2.imshow("Original Image",color_image)
# cv2.waitKey(0)

# %%
cv2.imshow("grayscale_image",grayscale_image)
# cv2.waitKey(0)
